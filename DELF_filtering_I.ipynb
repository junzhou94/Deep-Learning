# %%
import os
import csv
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt

test = pd.read_csv('test.csv')
test.shape
# Out:
# (117703, 2)

# %%
import tensorflow as tf
import tensorflow_hub as hub

# Prepare an image tensor.
def image_input_fn(path):
    image_contents = tf.read_file(path)
    image_tf = tf.image.decode_jpeg(image_contents, channels = 3)
    return tf.image.convert_image_dtype(image_tf, tf.float32)
        
# Set the threshold
threshold = 225   # 225???

# Instantiate the DELF module.
delf_module = hub.Module("https://tfhub.dev/google/delf/1")
# Out:
# INFO:tensorflow:Downloading TF-Hub Module 'https://tfhub.dev/google/delf/1'.
# INFO:tensorflow:Downloaded TF-Hub Module 'https://tfhub.dev/google/delf/1'.
# INFO:tensorflow:Initialize variable module/attonly/attention/compute/conv1/BatchNorm/beta:0 from checkpoint b'C:\\Users\\wangw\\AppData\\Local\\Temp\\tfhub_modules\\333559635dbfa88957ed2e7ed45bdbfe3353e356\\variables\\variables' with attonly/attention/compute/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable module/attonly/attention/compute/conv1/BatchNorm/gamma:0 from checkpoint b'C:\\Users\\wangw\\AppData\\Local\\Temp\\tfhub_modules\\333559635dbfa88957ed2e7ed45bdbfe3353e356\\variables\\variables' with attonly/attention/compute/conv1/BatchNorm/gamma
# ...

# %%
image_placeholder = tf.placeholder(tf.float32, shape=(None, None, 3), name='input_image')
delf_inputs = {
  # An image tensor with dtype float32 and shape [height, width, 3], where height and width are positive integers:
  'image': image_placeholder,
  # Scaling factors for building the image pyramid as described in the paper:
  'image_scales': [0.25, 0.3536, 0.5, 0.7071, 1.0, 1.4142, 2.0],
  # Image features whose attention score exceeds this threshold will be returned:
  'score_threshold': 100.0,
  # The maximum number of features that should be returned:
  'max_feature_num': 500,
}

# Apply the DELF module to the inputs to get the outputs.
delf_outputs = delf_module(delf_inputs, as_dict = True)

landmark_or_not = list()

cnt = 0
for test_idx in test.index[0:]:
    cnt += 1
    if cnt % 10000 == 0:
        print('test processing done {}'.format(cnt))

    img_id = str(test.loc[test_idx]['id'])
    path = '../data/test/' + img_id + '.jpg'    
        
    if os.path.exists(path):  
        
        image_tf = image_input_fn(path)
        
        with tf.train.MonitoredSession() as sess:    
            image = sess.run(image_tf)
            tmp = sess.run(delf_outputs['scores'], feed_dict = {image_placeholder: image})
            
        if tmp.transpose().mean() > threshold:
            landmark_or_not.append(tmp.transpose().mean())
        else:
            landmark_or_not.append(-1)
            
    else:
        print('no such image!')
        landmark_or_not.append(-1)
# Out:
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# no such image!
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# ...

# %%
tmp = np.array(landmark_or_not)
pd.DataFrame(tmp).to_csv('labels_DELF1_0_120000.csv', index = False)
tmp.shape
# Out:
# (2284,)

# %% [markdown]
# import numpy as np
# import pandas as pd
# import csv
#
# n = 5
#
# train = pd.read_csv('train2.csv')
# df_sample_n = pd.DataFrame()
#
# for i in range(14951):
#     if train[train['landmark_id'] == i].shape[0] >= n:
#         df_sample_n = pd.concat([df_sample_n, train[train['landmark_id'] == i].sample(n)], axis = 0)
#     else:
#         df_sample_n = pd.concat([df_sample_n, train[train['landmark_id'] == i]], axis = 0)
#
# df_sample_n

# %% [markdown]
# df_sample_n.to_csv('train_sample_5.csv', index = False)
